# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\d\Documents\Python\Hamoye_One_School\Regression_in_ML\energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights        T1      RH_1        T2  \
# 0  2016-01-11 17:00:00          60      30 19.890000 47.596667 19.200000
# 1  2016-01-11 17:10:00          60      30 19.890000 46.693333 19.200000
# 2  2016-01-11 17:20:00          50      30 19.890000 46.300000 19.200000
# 3  2016-01-11 17:30:00          50      40 19.890000 46.066667 19.200000
# 4  2016-01-11 17:40:00          60      40 19.890000 46.333333 19.200000
#
#        RH_2        T3      RH_3        T4  ...        T9      RH_9    T_out  \
# 0 44.790000 19.790000 44.730000 19.000000  ... 17.033333 45.530000 6.600000
# 1 44.722500 19.790000 44.790000 19.000000  ... 17.066667 45.560000 6.483333
# 2 44.626667 19.790000 44.933333 18.926667  ... 17.000000 45.500000 6.366667
# 3 44.590000 19.790000 45.000000 18.890000  ... 17.000000 45.400000 6.250000
# 4 44.530000 19.790000 45.000000 18.890000  ... 17.000000 45.400000 6.133333
#
# ...

# %%
df.describe(include='all')
# Out:
#                        date   Appliances       lights           T1  \
# count                 19735 19735.000000 19735.000000 19735.000000
# unique                19735          nan          nan          nan
# top     2016-05-08 18:50:00          nan          nan          nan
# freq                      1          nan          nan          nan
# mean                    NaN    97.694958     3.801875    21.686571
# std                     NaN   102.524891     7.935988     1.606066
# min                     NaN    10.000000     0.000000    16.790000
# 25%                     NaN    50.000000     0.000000    20.760000
# 50%                     NaN    60.000000     0.000000    21.600000
# 75%                     NaN   100.000000     0.000000    22.600000
# max                     NaN  1080.000000    70.000000    26.260000
#
#                RH_1           T2         RH_2           T3         RH_3  \
# count  19735.000000 19735.000000 19735.000000 19735.000000 19735.000000
# ...

# %%
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
simple_linear_reg_df = df[['T2', 'T6']]

print(simple_linear_reg_df)
# Out:
#              T2        T6
# 0     19.200000  7.026667
# 1     19.200000  6.833333
# 2     19.200000  6.560000
# 3     19.200000  6.433333
# 4     19.200000  6.366667
# ...         ...       ...
# 19730 25.890000 24.796667
# 19731 25.754000 24.196667
# 19732 25.628571 23.626667
# 19733 25.414000 22.433333
# 19734 25.264286 21.026667
#
# [19735 rows x 2 columns]

# %%
sns.regplot(x = "T2", y = "T6", data = simple_linear_reg_df)

# %%
df = df.drop(columns = ['date', 'lights'], axis = 1)

# %%
x = df['T2'].values.reshape(-1,1)
y = df['T6'].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
#training the algorithm
linear_model = LinearRegression()  
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = linear_model.predict(x_test)

# %%
df_new = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df_new
# Out:
#         Actual  Predicted
# 0     1.198571   2.155789
# 1     2.530000  10.011161
# 2    -0.266667   1.873916
# 3    11.160000  15.796987
# 4    -0.733333  -0.729706
# ...        ...        ...
# 5916  0.100000   9.803464
# 5917  8.660000   5.360247
# 5918  9.600000   4.247588
# 5919 13.195714   8.698223
# 5920 12.500000   4.989360
#
# [5921 rows x 2 columns]

# %%
# R-SQUARED
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, y_pred)
round(r2_score, 2)
# Out:
# 0.64

# %%
# MEAN ABSOLUTE ERROR
from sklearn.metrics import mean_absolute_error 
mae = mean_absolute_error(y_test, y_pred)
round(mae, 2)
# Out:
# 2.82

# %%
# RESIDUAL SUM OF SQUARES
import numpy as np
rss = np.sum(np.square(y_test - y_pred))
round(rss, 2)
# Out:
# 78033.97

# %%
# ROOT MEAN SQUARE ERROR
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 9.925

# %%
#For retrieving the slope:
print(linear_model.coef_)
# Out:
# [[2.22531769]]

# %%
# RIDGE REGRESSION
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha= 0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_pred1 = ridge_reg.predict(x_test)

# %%
df_1 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred1.flatten()})
df_1
# Out:
#         Actual  Predicted
# 0     1.198571   2.155824
# 1     2.530000  10.011148
# 2    -0.266667   1.873952
# 3    11.160000  15.796939
# 4    -0.733333  -0.729654
# ...        ...        ...
# 5916  0.100000   9.803453
# 5917  8.660000   5.360262
# 5918  9.600000   4.247610
# 5919 13.195714   8.698218
# 5920 12.500000   4.989378
#
# [5921 rows x 2 columns]

# %%
# ROOT MEAN SQUARE ERROR
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred1))
round(rmse, 3)
# Out:
# 3.63

# %%
# FEATURE SELECTION AND LASSO REGRESSION
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha= 0.001 )
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred2 =lasso_reg.predict(x_test)

# %%
df_2 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred2.flatten()})
df_2
# Out:
#         Actual  Predicted
# 0     1.198571   2.156325
# 1     2.530000  10.010963
# 2    -0.266667   1.874478
# 3    11.160000  15.796249
# 4    -0.733333  -0.728901
# ...        ...        ...
# 5916  0.100000   9.803286
# 5917  8.660000   5.360483
# 5918  9.600000   4.247928
# 5919 13.195714   8.698148
# 5920 12.500000   4.989632
#
# [5921 rows x 2 columns]

# %%
# ROOT MEAN SQUARE ERROR
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred2))
round(rmse, 3)
# Out:
# 3.63
